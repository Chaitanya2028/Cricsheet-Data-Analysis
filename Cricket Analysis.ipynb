# %%
import requests
import zipfile
import io
import pandas as pd
import ujson
from datetime import datetime
import numpy as np

def get_fielders(x):
    try:
        return ",".join([fielder['name'] for fielder in x['wickets'][0]['fielders']])
    except:
        return ""

def extra(x,y):
    if x == 'wides' or x == 'noballs' or x == '':
        return y
    elif x == 'byes, noballs' or x == 'legbyes, noballs':
        return 1
    elif x == 'penalty, wides':
        return y-5
    else:
        return 0

def extract_match_info(data):
    info = data.get('info', {})
    date = info.get('dates', ['Unknown'])[0]
    return {
        'date': date,
        'match_number':info.get('match_type_number','Unknown'),
        'match_type':info.get('match_type','Unknown'),
        'balls_per_over': info.get('balls_per_over','Unknown'),
        'overs':info.get('overs','Unknown'),
        'venue': info.get('venue', 'Unknown'),
        'city':info.get('city','Unknown'),
        'season':info.get('season',''),
        'team_type':info.get('team_type',''),
        'teams': info.get('teams', []),
        'event_name': info.get('event', {}).get('name', 'Unknown'),
        'event_match_no': info.get('event', {}).get('match_number', 'Unknown'),
        'stage': info.get('event', {}).get('stage', 'Unknown'),
        'gender': info.get('gender', 'Unknown'),
        'outcome_winner': info.get('outcome', {}).get('winner', 'Unknown'),
        'outcome_by': info.get('outcome', {}).get('by', {}),
        'superover_win': info.get('outcome', {}).get('eliminator', 'NA'),
        'match_result': info.get('outcome', {}).get('result', 'NA'),
        'method':info.get('outcome', {}).get('method', 'NA'),
        'player_of_match': info.get('player_of_match', ['Unknown'])[0],
        'toss_winner': info.get('toss', {}).get('winner', 'Unknown'),
        'toss_decision': info.get('toss', {}).get('decision', 'Unknown'),
        'date_obj': datetime.strptime(date, '%Y-%m-%d'),
    }

def process_json_data(json_data, matchid):
    match_info = extract_match_info(json_data)
    all_data = []

    innings_number = 0
    res = ""
    for key, value in match_info["outcome_by"].items():
        res = str(value) + " " + key

    for innings in json_data.get('innings', []):
        team_name = innings['team']
        innings_number += 1
        positions = {}
        position = 1
        wickets = 0
        team_runs = 0
        team_balls = 0

        for over in innings.get('overs', []):
            valid_ball_number = 1
            for delivery in over['deliveries']:
                next_batter = None
                ball_faced = 0
                valid_ball = 0
                is_wide = 'wides' in delivery.get('extras', {})
                is_noball = 'noballs' in delivery.get('extras', {})
                if not is_wide:
                    ball_faced += 1
                if not (is_wide or is_noball):
                    ball_number = valid_ball_number
                    valid_ball_number += 1
                    valid_ball = 1
                else:
                    ball_number = valid_ball_number
                    valid_ball = 0

                if delivery.get('wickets') and delivery['wickets'][0].get('kind') not in ['retired hurt', 'retired not out']:
                    wickets += 1

                if delivery["batter"] not in positions:
                    positions[delivery['batter']] = position
                    position += 1
                    if wickets >= 1 and over['over'] + 0.1 * ball_number > 0.1:
                        next_batter = delivery['batter']               

                if delivery["non_striker"] not in positions:
                    positions[delivery['non_striker']] = position
                    position += 1
                    if wickets >= 1 and over['over'] + 0.1 * ball_number > 0.1:
                        next_batter = delivery['non_striker']

                team_runs += delivery.get('runs', {}).get('total', 0)
                team_balls += valid_ball

                all_data.append({
                    'match_id': matchid,
                    'date': match_info['date'],
                    'match_type': match_info['match_type'],
                    'event_name': match_info['event_name'],
                    'innings': innings_number,
                    'match_id_inn': matchid+'-'+str(innings_number),
                    'batting_team': team_name,
                    'bowling_team': next((team for team in match_info['teams'] if team != team_name), 'Unknown'),
                    'over': over['over'],
                    'ball': ball_number,
                    'ball_no': over['over'] + 0.1 * ball_number,
                    'batter': delivery["batter"],
                    'bat_pos': positions[delivery["batter"]],
                    'runs_batter': delivery.get('runs', {}).get('batter', 0),
                    'balls_faced': ball_faced,
                    'bowler': delivery["bowler"],
                    'valid_ball': valid_ball,
                    'runs_extras': delivery.get('runs', {}).get('extras', 0),
                    'runs_total': delivery.get('runs', {}).get('total', 0),
                    'runs_bowler': delivery.get('runs', {}).get('batter', 0) + extra(', '.join(delivery.get('extras', {}).keys()), delivery.get('runs', {}).get('extras', 0)),
                    'runs_not_boundary': delivery.get('runs', {}).get('non_boundary', False),
                    'extra_type': ', '.join(delivery.get('extras', {}).keys()),
                    'non_striker': delivery["non_striker"],
                    'non_striker_pos': positions[delivery['non_striker']],
                    'wicket_kind': delivery['wickets'][0].get('kind') if delivery.get('wickets') else None,
                    'player_out': delivery['wickets'][0].get('player_out') if delivery.get('wickets') else None, 
                    'fielders': get_fielders(delivery),
                    'runs_target': innings.get("target", {}).get("runs"),
                    'review_batter': delivery.get('review', {}).get('batter', ""),
                    'team_reviewed': delivery.get('review', {}).get('by', ""),
                    'review_decision': delivery.get('review', {}).get('decision', ""),
                    'umpire': delivery.get('review', {}).get('umpire', ""),
                    'umpires_call': delivery.get('review', {}).get('umpires_call', False),
                    'player_of_match': match_info['player_of_match'],
                    'match_won_by': match_info["outcome_winner"],
                    'win_outcome': res,
                    'toss_winner': match_info['toss_winner'],
                    'toss_decision': match_info['toss_decision'],
                    'venue': match_info['venue'],
                    'city': match_info['city'],
                    'day': match_info['date_obj'].day,
                    'month': match_info['date_obj'].month,
                    'year': match_info['date_obj'].year,
                    'season': match_info['season'],
                    'gender': match_info['gender'],
                    'team_type': match_info['team_type'],
                    'superover_winner': match_info['superover_win'],
                    'result_type': match_info['match_result'],
                    'method': match_info['method'],
                    'balls_per_over': match_info['balls_per_over'],
                    'overs': match_info['overs'],
                    'event_match_no': match_info['event_match_no'],
                    'stage': match_info['stage'],
                    'match_number': match_info['match_number'],
                    'team_runs': team_runs,
                    'team_balls': team_balls,
                    'team_wicket': wickets,
                    'new_batter': next_batter,
                })
    return all_data

# %%
def main():
    url = 'https://cricsheet.org/downloads/odis_male_json.zip'
    
    response = requests.get(url)
    response.raise_for_status() 
    
    with zipfile.ZipFile(io.BytesIO(response.content)) as z:
        data_batches = []
        count = 0
        print('Zip file Loaded')
        for filename in z.namelist():
            if filename.endswith('.json'):
                count += 1
                print(f"match:{count}")
                with z.open(filename) as file:
                    json_data = ujson.load(file)
                    match_id = filename.split("/")[-1].split(".")[0]
                    processed_data = process_json_data(json_data, match_id)
                    data_batches.append(processed_data)
    
    combined_data = [item for sublist in data_batches for item in sublist]
    df = pd.DataFrame(combined_data).sort_values(by=["date", "match_id", "innings", "over", "ball"])
    df['batter_runs'] = df.groupby(['match_id', 'innings', 'batter'])['runs_batter'].cumsum()
    df['batter_balls'] = df.groupby(['match_id', 'innings', 'batter'])['balls_faced'].cumsum()
    df['bowler_wicket'] = (~df['wicket_kind'].isin([None, 'obstructing the field', 'retired hurt', 'run out','retired not out'])).astype(int)
    df['batting_partners'] = df.apply(lambda row: tuple(sorted([row['batter'], row['non_striker']])), axis=1)
    df['next_batter'] = df['new_batter'].shift(-1)
    
    return df

df = main()
df
# Out:
# Zip file Loaded
# match:1
# match:2
# match:3
# match:4
# match:5
# match:6
# match:7
# match:8
# match:9
# match:10
# match:11
# match:12
# match:13
# match:14
# match:15
# match:16
# match:17
# match:18
# match:19
# match:20
# match:21
# match:22
# match:23
# match:24
# match:25
# match:26
# match:27
# match:28
# match:29
# match:30
# match:31
# match:32
# match:33
# match:34
# match:35
# match:36
# match:37
# match:38
# match:39
# match:40
# match:41
# match:42
# match:43
# match:44
# match:45
# match:46
# match:47
# match:48
# match:49
# match:50
# match:51
# match:52
# match:53
# match:54
# match:55
# match:56
# match:57
# match:58
# match:59
# match:60
# match:61
# match:62
# match:63
# match:64
# match:65
# match:66
# match:67
# match:68
# match:69
# match:70
# match:71
# match:72
# match:73
# match:74
# match:75
# match:76
# match:77
# match:78
# match:79
# match:80
# match:81
# match:82
# match:83
# match:84
# match:85
# match:86
# match:87
# match:88
# match:89
# match:90
# match:91
# match:92
# match:93
# match:94
# match:95
# match:96
# match:97
# match:98
# match:99
# match:100
# match:101
# match:102
# match:103
# match:104
# match:105
# match:106
# match:107
# match:108
# match:109
# match:110
# match:111
# match:112
# match:113
# match:114
# match:115
# match:116
# match:117
# match:118
# match:119
# match:120
# match:121
# match:122
# match:123
# match:124
# match:125
# match:126
# match:127
# match:128
# match:129
# match:130
# match:131
# match:132
# match:133
# match:134
# match:135
# match:136
# match:137
# match:138
# match:139
# match:140
# match:141
# match:142
# match:143
# match:144
# match:145
# match:146
# match:147
# match:148
# match:149
# match:150
# match:151
# match:152
# match:153
# match:154
# match:155
# match:156
# match:157
# match:158
# match:159
# match:160
# match:161
# match:162
# match:163
# match:164
# match:165
# match:166
# match:167
# match:168
# match:169
# match:170
# match:171
# match:172
# match:173
# match:174
# match:175
# match:176
# match:177
# match:178
# match:179
# match:180
# match:181
# match:182
# match:183
# match:184
# match:185
# match:186
# match:187
# match:188
# match:189
# match:190
# match:191
# match:192
# match:193
# match:194
# match:195
# match:196
# match:197
# match:198
# match:199
# match:200
# match:201
# match:202
# match:203
# match:204
# match:205
# match:206
# match:207
# match:208
# match:209
# match:210
# match:211
# match:212
# match:213
# match:214
# match:215
# match:216
# match:217
# match:218
# match:219
# match:220
# match:221
# match:222
# match:223
# match:224
# match:225
# match:226
# match:227
# match:228
# match:229
# match:230
# match:231
# match:232
# match:233
# match:234
# match:235
# match:236
# match:237
# match:238
# match:239
# match:240
# match:241
# match:242
# match:243
# match:244
# match:245
# match:246
# match:247
# match:248
# match:249
# match:250
# match:251
# match:252
# match:253
# match:254
# match:255
# match:256
# match:257
# match:258
# match:259
# match:260
# match:261
# match:262
# match:263
# match:264
# match:265
# match:266
# match:267
# match:268
# match:269
# match:270
# match:271
# match:272
# match:273
# match:274
# match:275
# match:276
# match:277
# match:278
# match:279
# match:280
# match:281
# match:282
# match:283
# match:284
# match:285
# match:286
# match:287
# match:288
# match:289
# match:290
# match:291
# match:292
# match:293
# match:294
# match:295
# match:296
# match:297
# match:298
# match:299
# match:300
# match:301
# match:302
# match:303
# match:304
# match:305
# match:306
# match:307
# match:308
# match:309
# match:310
# match:311
# match:312
# match:313
# match:314
# match:315
# match:316
# match:317
# match:318
# match:319
# match:320
# match:321
# match:322
# match:323
# match:324
# match:325
# match:326
# match:327
# match:328
# match:329
# match:330
# match:331
# match:332
# match:333
# match:334
# match:335
# match:336
# match:337
# match:338
# match:339
# match:340
# match:341
# match:342
# match:343
# match:344
# match:345
# match:346
# match:347
# match:348
# match:349
# match:350
# match:351
# match:352
# match:353
# match:354
# match:355
# match:356
# match:357
# match:358
# match:359
# match:360
# match:361
# match:362
# match:363
# match:364
# match:365
# match:366
# match:367
# match:368
# match:369
# match:370
# match:371
# match:372
# match:373
# match:374
# match:375
# match:376
# match:377
# match:378
# match:379
# match:380
# match:381
# match:382
# match:383
# match:384
# match:385
# match:386
# match:387
# match:388
# match:389
# match:390
# match:391
# match:392
# match:393
# match:394
# match:395
# match:396
# match:397
# match:398
# match:399
# match:400
# match:401
# match:402
# match:403
# match:404
# match:405
# match:406
# match:407
# match:408
# match:409
# match:410
# match:411
# match:412
# match:413
# match:414
# match:415
# match:416
# match:417
# match:418
# match:419
# match:420
# match:421
# match:422
# match:423
# match:424
# match:425
# match:426
# match:427
# match:428
# match:429
# match:430
# match:431
# match:432
# match:433
# match:434
# match:435
# match:436
# match:437
# match:438
# match:439
# match:440
# match:441
# match:442
# match:443
# match:444
# match:445
# match:446
# match:447
# match:448
# match:449
# match:450
# match:451
# match:452
# match:453
# match:454
# match:455
# match:456
# match:457
# match:458
# match:459
# match:460
# match:461
# match:462
# match:463
# match:464
# match:465
# match:466
# match:467
# match:468
# match:469
# match:470
# match:471
# match:472
# match:473
# match:474
# match:475
# match:476
# match:477
# match:478
# match:479
# match:480
# match:481
# match:482
# match:483
# match:484
# match:485
# match:486
# match:487
# match:488
# match:489
# match:490
# match:491
# match:492
# match:493
# match:494
# match:495
# match:496
# match:497
# match:498
# match:499
# match:500
# match:501
# match:502
# match:503
# match:504
# match:505
# match:506
# match:507
# match:508
# match:509
# match:510
# match:511
# match:512
# match:513
# match:514
# match:515
# match:516
# match:517
# match:518
# match:519
# match:520
# match:521
# match:522
# match:523
# match:524
# match:525
# match:526
# match:527
# match:528
# match:529
# match:530
# match:531
# match:532
# match:533
# match:534
# match:535
# match:536
# match:537
# match:538
# match:539
# match:540
# match:541
# match:542
# match:543
# match:544
# match:545
# match:546
# match:547
# match:548
# match:549
# match:550
# match:551
# match:552
# match:553
# match:554
# match:555
# match:556
# match:557
# match:558
# match:559
# match:560
# match:561
# match:562
# match:563
# match:564
# match:565
# match:566
# match:567
# match:568
# match:569
# match:570
# match:571
# match:572
# match:573
# match:574
# match:575
# match:576
# match:577
# match:578
# match:579
# match:580
# match:581
# match:582
# match:583
# match:584
# match:585
# match:586
# match:587
# match:588
# match:589
# match:590
# match:591
# match:592
# match:593
# match:594
# match:595
# match:596
# match:597
# match:598
# match:599
# match:600
# match:601
# match:602
# match:603
# match:604
# match:605
# match:606
# match:607
# match:608
# match:609
# match:610
# match:611
# match:612
# match:613
# match:614
# match:615
# match:616
# match:617
# match:618
# match:619
# match:620
# match:621
# match:622
# match:623
# match:624
# match:625
# match:626
# match:627
# match:628
# match:629
# match:630
# match:631
# match:632
# match:633
# match:634
# match:635
# match:636
# match:637
# match:638
# match:639
# match:640
# match:641
# match:642
# match:643
# match:644
# match:645
# match:646
# match:647
# match:648
# match:649
# match:650
# match:651
# match:652
# match:653
# match:654
# match:655
# match:656
# match:657
# match:658
# match:659
# match:660
# match:661
# match:662
# match:663
# match:664
# match:665
# match:666
# match:667
# match:668
# match:669
# match:670
# match:671
# match:672
# match:673
# match:674
# match:675
# match:676
# match:677
# match:678
# match:679
# match:680
# match:681
# match:682
# match:683
# match:684
# match:685
# match:686
# match:687
# match:688
# match:689
# match:690
# match:691
# match:692
# match:693
# match:694
# match:695
# match:696
# match:697
# match:698
# match:699
# match:700
# match:701
# match:702
# match:703
# match:704
# match:705
# match:706
# match:707
# match:708
# match:709
# match:710
# match:711
# match:712
# match:713
# match:714
# match:715
# match:716
# match:717
# match:718
# match:719
# match:720
# match:721
# match:722
# match:723
# match:724
# match:725
# match:726
# match:727
# match:728
# match:729
# match:730
# match:731
# match:732
# match:733
# match:734
# match:735
# match:736
# match:737
# match:738
# match:739
# match:740
# match:741
# match:742
# match:743
# match:744
# match:745
# match:746
# match:747
# match:748
# match:749
# match:750
# match:751
# match:752
# match:753
# match:754
# match:755
# match:756
# match:757
# match:758
# match:759
# match:760
# match:761
# match:762
# match:763
# match:764
# match:765
# match:766
# match:767
# match:768
# match:769
# match:770
# match:771
# match:772
# match:773
# match:774
# match:775
# match:776
# match:777
# match:778
# match:779
# match:780
# match:781
# match:782
# match:783
# match:784
# match:785
# match:786
# match:787
# match:788
# match:789
# match:790
# match:791
# match:792
# match:793
# match:794
# match:795
# match:796
# match:797
# match:798
# match:799
# match:800
# match:801
# match:802
# match:803
# match:804
# match:805
# match:806
# match:807
# match:808
# match:809
# match:810
# match:811
# match:812
# match:813
# match:814
# match:815
# match:816
# match:817
# match:818
# match:819
# match:820
# match:821
# match:822
# match:823
# match:824
# match:825
# match:826
# match:827
# match:828
# match:829
# match:830
# match:831
# match:832
# match:833
# match:834
# match:835
# match:836
# match:837
# match:838
# match:839
# match:840
# match:841
# match:842
# match:843
# match:844
# match:845
# match:846
# match:847
# match:848
# match:849
# match:850
# match:851
# match:852
# match:853
# match:854
# match:855
# match:856
# match:857
# match:858
# match:859
# match:860
# match:861
# match:862
# match:863
# match:864
# match:865
# match:866
# match:867
# match:868
# match:869
# match:870
# match:871
# match:872
# match:873
# match:874
# match:875
# match:876
# match:877
# match:878
# match:879
# match:880
# match:881
# match:882
# match:883
# match:884
# match:885
# match:886
# match:887
# match:888
# match:889
# match:890
# match:891
# match:892
# match:893
# match:894
# match:895
# match:896
# match:897
# match:898
# match:899
# match:900
# match:901
# match:902
# match:903
# match:904
# match:905
# match:906
# match:907
# match:908
# match:909
# match:910
# match:911
# match:912
# match:913
# match:914
# match:915
# match:916
# match:917
# match:918
# match:919
# match:920
# match:921
# match:922
# match:923
# match:924
# match:925
# match:926
# match:927
# match:928
# match:929
# match:930
# match:931
# match:932
# match:933
# match:934
# match:935
# match:936
# match:937
# match:938
# match:939
# match:940
# match:941
# match:942
# match:943
# match:944
# match:945
# match:946
# match:947
# match:948
# match:949
# match:950
# match:951
# match:952
# match:953
# match:954
# match:955
# match:956
# match:957
# match:958
# match:959
# match:960
# match:961
# match:962
# match:963
# match:964
# match:965
# match:966
# match:967
# match:968
# match:969
# match:970
# match:971
# match:972
# match:973
# match:974
# match:975
# match:976
# match:977
# match:978
# match:979
# match:980
# match:981
# match:982
# match:983
# match:984
# match:985
# match:986
# match:987
# match:988
# match:989
# match:990
# match:991
# match:992
# match:993
# match:994
# match:995
# match:996
# match:997
# match:998
# match:999
# match:1000
# match:1001
# match:1002
# match:1003
# match:1004
# match:1005
# match:1006
# match:1007
# match:1008
# match:1009
# match:1010
# match:1011
# match:1012
# match:1013
# match:1014
# match:1015
# match:1016
# match:1017
# match:1018
# match:1019
# match:1020
# match:1021
# match:1022
# match:1023
# match:1024
# match:1025
# match:1026
# match:1027
# match:1028
# match:1029
# match:1030
# match:1031
# match:1032
# match:1033
# match:1034
# match:1035
# match:1036
# match:1037
# match:1038
# match:1039
# match:1040
# match:1041
# match:1042
# match:1043
# match:1044
# match:1045
# match:1046
# match:1047
# match:1048
# match:1049
# match:1050
# match:1051
# match:1052
# match:1053
# match:1054
# match:1055
# match:1056
# match:1057
# match:1058
# match:1059
# match:1060
# match:1061
# match:1062
# match:1063
# match:1064
# match:1065
# match:1066
# match:1067
# match:1068
# match:1069
# match:1070
# match:1071
# match:1072
# match:1073
# match:1074
# match:1075
# match:1076
# match:1077
# match:1078
# match:1079
# match:1080
# match:1081
# match:1082
# match:1083
# match:1084
# match:1085
# match:1086
# match:1087
# match:1088
# match:1089
# match:1090
# match:1091
# match:1092
# match:1093
# match:1094
# match:1095
# match:1096
# match:1097
# match:1098
# match:1099
# match:1100
# match:1101
# match:1102
# match:1103
# match:1104
# match:1105
# match:1106
# match:1107
# match:1108
# match:1109
# match:1110
# match:1111
# match:1112
# match:1113
# match:1114
# match:1115
# match:1116
# match:1117
# match:1118
# match:1119
# match:1120
# match:1121
# match:1122
# match:1123
# match:1124
# match:1125
# match:1126
# match:1127
# match:1128
# match:1129
# match:1130
# match:1131
# match:1132
# match:1133
# match:1134
# match:1135
# match:1136
# match:1137
# match:1138
# match:1139
# match:1140
# match:1141
# match:1142
# match:1143
# match:1144
# match:1145
# match:1146
# match:1147
# match:1148
# match:1149
# match:1150
# match:1151
# match:1152
# match:1153
# match:1154
# match:1155
# match:1156
# match:1157
# match:1158
# match:1159
# match:1160
# match:1161
# match:1162
# match:1163
# match:1164
# match:1165
# match:1166
# match:1167
# match:1168
# match:1169
# match:1170
# match:1171
# match:1172
# match:1173
# match:1174
# match:1175
# match:1176
# match:1177
# match:1178
# match:1179
# match:1180
# match:1181
# match:1182
# match:1183
# match:1184
# match:1185
# match:1186
# match:1187
# match:1188
# match:1189
# match:1190
# match:1191
# match:1192
# match:1193
# match:1194
# match:1195
# match:1196
# match:1197
# match:1198
# match:1199
# match:1200
# match:1201
# match:1202
# match:1203
# match:1204
# match:1205
# match:1206
# match:1207
# match:1208
# match:1209
# match:1210
# match:1211
# match:1212
# match:1213
# match:1214
# match:1215
# match:1216
# match:1217
# match:1218
# match:1219
# match:1220
# match:1221
# match:1222
# match:1223
# match:1224
# match:1225
# match:1226
# match:1227
# match:1228
# match:1229
# match:1230
# match:1231
# match:1232
# match:1233
# match:1234
# match:1235
# match:1236
# match:1237
# match:1238
# match:1239
# match:1240
# match:1241
# match:1242
# match:1243
# match:1244
# match:1245
# match:1246
# match:1247
# match:1248
# match:1249
# match:1250
# match:1251
# match:1252
# match:1253
# match:1254
# match:1255
# match:1256
# match:1257
# match:1258
# match:1259
# match:1260
# match:1261
# match:1262
# match:1263
# match:1264
# match:1265
# match:1266
# match:1267
# match:1268
# match:1269
# match:1270
# match:1271
# match:1272
# match:1273
# match:1274
# match:1275
# match:1276
# match:1277
# match:1278
# match:1279
# match:1280
# match:1281
# match:1282
# match:1283
# match:1284
# match:1285
# match:1286
# match:1287
# match:1288
# match:1289
# match:1290
# match:1291
# match:1292
# match:1293
# match:1294
# match:1295
# match:1296
# match:1297
# match:1298
# match:1299
# match:1300
# match:1301
# match:1302
# match:1303
# match:1304
# match:1305
# match:1306
# match:1307
# match:1308
# match:1309
# match:1310
# match:1311
# match:1312
# match:1313
# match:1314
# match:1315
# match:1316
# match:1317
# match:1318
# match:1319
# match:1320
# match:1321
# match:1322
# match:1323
# match:1324
# match:1325
# match:1326
# match:1327
# match:1328
# match:1329
# match:1330
# match:1331
# match:1332
# match:1333
# match:1334
# match:1335
# match:1336
# match:1337
# match:1338
# match:1339
# match:1340
# match:1341
# match:1342
# match:1343
# match:1344
# match:1345
# match:1346
# match:1347
# match:1348
# match:1349
# match:1350
# match:1351
# match:1352
# match:1353
# match:1354
# match:1355
# match:1356
# match:1357
# match:1358
# match:1359
# match:1360
# match:1361
# match:1362
# match:1363
# match:1364
# match:1365
# match:1366
# match:1367
# match:1368
# match:1369
# match:1370
# match:1371
# match:1372
# match:1373
# match:1374
# match:1375
# match:1376
# match:1377
# match:1378
# match:1379
# match:1380
# match:1381
# match:1382
# match:1383
# match:1384
# match:1385
# match:1386
# match:1387
# match:1388
# match:1389
# match:1390
# match:1391
# match:1392
# match:1393
# match:1394
# match:1395
# match:1396
# match:1397
# match:1398
# match:1399
# match:1400
# match:1401
# match:1402
# match:1403
# match:1404
# match:1405
# match:1406
# match:1407
# match:1408
# match:1409
# match:1410
# match:1411
# match:1412
# match:1413
# match:1414
# match:1415
# match:1416
# match:1417
# match:1418
# match:1419
# match:1420
# match:1421
# match:1422
# match:1423
# match:1424
# match:1425
# match:1426
# match:1427
# match:1428
# match:1429
# match:1430
# match:1431
# match:1432
# match:1433
# match:1434
# match:1435
# match:1436
# match:1437
# match:1438
# match:1439
# match:1440
# match:1441
# match:1442
# match:1443
# match:1444
# match:1445
# match:1446
# match:1447
# match:1448
# match:1449
# match:1450
# match:1451
# match:1452
# match:1453
# match:1454
# match:1455
# match:1456
# match:1457
# match:1458
# match:1459
# match:1460
# match:1461
# match:1462
# match:1463
# match:1464
# match:1465
# match:1466
# match:1467
# match:1468
# match:1469
# match:1470
# match:1471
# match:1472
# match:1473
# match:1474
# match:1475
# match:1476
# match:1477
# match:1478
# match:1479
# match:1480
# match:1481
# match:1482
# match:1483
# match:1484
# match:1485
# match:1486
# match:1487
# match:1488
# match:1489
# match:1490
# match:1491
# match:1492
# match:1493
# match:1494
# match:1495
# match:1496
# match:1497
# match:1498
# match:1499
# match:1500
# match:1501
# match:1502
# match:1503
# match:1504
# match:1505
# match:1506
# match:1507
# match:1508
# match:1509
# match:1510
# match:1511
# match:1512
# match:1513
# match:1514
# match:1515
# match:1516
# match:1517
# match:1518
# match:1519
# match:1520
# match:1521
# match:1522
# match:1523
# match:1524
# match:1525
# match:1526
# match:1527
# match:1528
# match:1529
# match:1530
# match:1531
# match:1532
# match:1533
# match:1534
# match:1535
# match:1536
# match:1537
# match:1538
# match:1539
# match:1540
# match:1541
# match:1542
# match:1543
# match:1544
# match:1545
# match:1546
# match:1547
# match:1548
# match:1549
# match:1550
# match:1551
# match:1552
# match:1553
# match:1554
# match:1555
# match:1556
# match:1557
# match:1558
# match:1559
# match:1560
# match:1561
# match:1562
# match:1563
# match:1564
# match:1565
# match:1566
# match:1567
# match:1568
# match:1569
# match:1570
# match:1571
# match:1572
# match:1573
# match:1574
# match:1575
# match:1576
# match:1577
# match:1578
# match:1579
# match:1580
# match:1581
# match:1582
# match:1583
# match:1584
# match:1585
# match:1586
# match:1587
# match:1588
# match:1589
# match:1590
# match:1591
# match:1592
# match:1593
# match:1594
# match:1595
# match:1596
# match:1597
# match:1598
# match:1599
# match:1600
# match:1601
# match:1602
# match:1603
# match:1604
# match:1605
# match:1606
# match:1607
# match:1608
# match:1609
# match:1610
# match:1611
# match:1612
# match:1613
# match:1614
# match:1615
# match:1616
# match:1617
# match:1618
# match:1619
# match:1620
# match:1621
# match:1622
# match:1623
# match:1624
# match:1625
# match:1626
# match:1627
# match:1628
# match:1629
# match:1630
# match:1631
# match:1632
# match:1633
# match:1634
# match:1635
# match:1636
# match:1637
# match:1638
# match:1639
# match:1640
# match:1641
# match:1642
# match:1643
# match:1644
# match:1645
# match:1646
# match:1647
# match:1648
# match:1649
# match:1650
# match:1651
# match:1652
# match:1653
# match:1654
# match:1655
# match:1656
# match:1657
# match:1658
# match:1659
# match:1660
# match:1661
# match:1662
# match:1663
# match:1664
# match:1665
# match:1666
# match:1667
# match:1668
# match:1669
# match:1670
# match:1671
# match:1672
# match:1673
# match:1674
# match:1675
# match:1676
# match:1677
# match:1678
# match:1679
# match:1680
# match:1681
# match:1682
# match:1683
# match:1684
# match:1685
# match:1686
# match:1687
# match:1688
# match:1689
# match:1690
# match:1691
# match:1692
# match:1693
# match:1694
# match:1695
# match:1696
# match:1697
# match:1698
# match:1699
# match:1700
# match:1701
# match:1702
# match:1703
# match:1704
# match:1705
# match:1706
# match:1707
# match:1708
# match:1709
# match:1710
# match:1711
# match:1712
# match:1713
# match:1714
# match:1715
# match:1716
# match:1717
# match:1718
# match:1719
# match:1720
# match:1721
# match:1722
# match:1723
# match:1724
# match:1725
# match:1726
# match:1727
# match:1728
# match:1729
# match:1730
# match:1731
# match:1732
# match:1733
# match:1734
# match:1735
# match:1736
# match:1737
# match:1738
# match:1739
# match:1740
# match:1741
# match:1742
# match:1743
# match:1744
# match:1745
# match:1746
# match:1747
# match:1748
# match:1749
# match:1750
# match:1751
# match:1752
# match:1753
# match:1754
# match:1755
# match:1756
# match:1757
# match:1758
# match:1759
# match:1760
# match:1761
# match:1762
# match:1763
# match:1764
# match:1765
# match:1766
# match:1767
# match:1768
# match:1769
# match:1770
# match:1771
# match:1772
# match:1773
# match:1774
# match:1775
# match:1776
# match:1777
# match:1778
# match:1779
# match:1780
# match:1781
# match:1782
# match:1783
# match:1784
# match:1785
# match:1786
# match:1787
# match:1788
# match:1789
# match:1790
# match:1791
# match:1792
# match:1793
# match:1794
# match:1795
# match:1796
# match:1797
# match:1798
# match:1799
# match:1800
# match:1801
# match:1802
# match:1803
# match:1804
# match:1805
# match:1806
# match:1807
# match:1808
# match:1809
# match:1810
# match:1811
# match:1812
# match:1813
# match:1814
# match:1815
# match:1816
# match:1817
# match:1818
# match:1819
# match:1820
# match:1821
# match:1822
# match:1823
# match:1824
# match:1825
# match:1826
# match:1827
# match:1828
# match:1829
# match:1830
# match:1831
# match:1832
# match:1833
# match:1834
# match:1835
# match:1836
# match:1837
# match:1838
# match:1839
# match:1840
# match:1841
# match:1842
# match:1843
# match:1844
# match:1845
# match:1846
# match:1847
# match:1848
# match:1849
# match:1850
# match:1851
# match:1852
# match:1853
# match:1854
# match:1855
# match:1856
# match:1857
# match:1858
# match:1859
# match:1860
# match:1861
# match:1862
# match:1863
# match:1864
# match:1865
# match:1866
# match:1867
# match:1868
# match:1869
# match:1870
# match:1871
# match:1872
# match:1873
# match:1874
# match:1875
# match:1876
# match:1877
# match:1878
# match:1879
# match:1880
# match:1881
# match:1882
# match:1883
# match:1884
# match:1885
# match:1886
# match:1887
# match:1888
# match:1889
# match:1890
# match:1891
# match:1892
# match:1893
# match:1894
# match:1895
# match:1896
# match:1897
# match:1898
# match:1899
# match:1900
# match:1901
# match:1902
# match:1903
# match:1904
# match:1905
# match:1906
# match:1907
# match:1908
# match:1909
# match:1910
# match:1911
# match:1912
# match:1913
# match:1914
# match:1915
# match:1916
# match:1917
# match:1918
# match:1919
# match:1920
# match:1921
# match:1922
# match:1923
# match:1924
# match:1925
# match:1926
# match:1927
# match:1928
# match:1929
# match:1930
# match:1931
# match:1932
# match:1933
# match:1934
# match:1935
# match:1936
# match:1937
# match:1938
# match:1939
# match:1940
# match:1941
# match:1942
# match:1943
# match:1944
# match:1945
# match:1946
# match:1947
# match:1948
# match:1949
# match:1950
# match:1951
# match:1952
# match:1953
# match:1954
# match:1955
# match:1956
# match:1957
# match:1958
# match:1959
# match:1960
# match:1961
# match:1962
# match:1963
# match:1964
# match:1965
# match:1966
# match:1967
# match:1968
# match:1969
# match:1970
# match:1971
# match:1972
# match:1973
# match:1974
# match:1975
# match:1976
# match:1977
# match:1978
# match:1979
# match:1980
# match:1981
# match:1982
# match:1983
# match:1984
# match:1985
# match:1986
# match:1987
# match:1988
# match:1989
# match:1990
# match:1991
# match:1992
# match:1993
# match:1994
# match:1995
# match:1996
# match:1997
# match:1998
# match:1999
# match:2000
# match:2001
# match:2002
# match:2003
# match:2004
# match:2005
# match:2006
# match:2007
# match:2008
# match:2009
# match:2010
# match:2011
# match:2012
# match:2013
# match:2014
# match:2015
# match:2016
# match:2017
# match:2018
# match:2019
# match:2020
# match:2021
# match:2022
# match:2023
# match:2024
# match:2025
# match:2026
# match:2027
# match:2028
# match:2029
# match:2030
# match:2031
# match:2032
# match:2033
# match:2034
# match:2035
# match:2036
# match:2037
# match:2038
# match:2039
# match:2040
# match:2041
# match:2042
# match:2043
# match:2044
# match:2045
# match:2046
# match:2047
# match:2048
# match:2049
# match:2050
# match:2051
# match:2052
# match:2053
# match:2054
# match:2055
# match:2056
# match:2057
# match:2058
# match:2059
# match:2060
# match:2061
# match:2062
# match:2063
# match:2064
# match:2065
# match:2066
# match:2067
# match:2068
# match:2069
# match:2070
# match:2071
# match:2072
# match:2073
# match:2074
# match:2075
# match:2076
# match:2077
# match:2078
# match:2079
# match:2080
# match:2081
# match:2082
# match:2083
# match:2084
# match:2085
# match:2086
# match:2087
# match:2088
# match:2089
# match:2090
# match:2091
# match:2092
# match:2093
# match:2094
# match:2095
# match:2096
# match:2097
# match:2098
# match:2099
# match:2100
# match:2101
# match:2102
# match:2103
# match:2104
# match:2105
# match:2106
# match:2107
# match:2108
# match:2109
# match:2110
# match:2111
# match:2112
# match:2113
# match:2114
# match:2115
# match:2116
# match:2117
# match:2118
# match:2119
# match:2120
# match:2121
# match:2122
# match:2123
# match:2124
# match:2125
# match:2126
# match:2127
# match:2128
# match:2129
# match:2130
# match:2131
# match:2132
# match:2133
# match:2134
# match:2135
# match:2136
# match:2137
# match:2138
# match:2139
# match:2140
# match:2141
# match:2142
# match:2143
# match:2144
# match:2145
# match:2146
# match:2147
# match:2148
# match:2149
# match:2150
# match:2151
# match:2152
# match:2153
# match:2154
# match:2155
# match:2156
# match:2157
# match:2158
# match:2159
# match:2160
# match:2161
# match:2162
# match:2163
# match:2164
# match:2165
# match:2166
# match:2167
# match:2168
# match:2169
# match:2170
# match:2171
# match:2172
# match:2173
# match:2174
# match:2175
# match:2176
# match:2177
# match:2178
# match:2179
# match:2180
# match:2181
# match:2182
# match:2183
# match:2184
# match:2185
# match:2186
# match:2187
# match:2188
# match:2189
# match:2190
# match:2191
# match:2192
# match:2193
# match:2194
# match:2195
# match:2196
# match:2197
# match:2198
# match:2199
# match:2200
# match:2201
# match:2202
# match:2203
# match:2204
# match:2205
# match:2206
# match:2207
# match:2208
# match:2209
# match:2210
# match:2211
# match:2212
# match:2213
# match:2214
# match:2215
# match:2216
# match:2217
# match:2218
# match:2219
# match:2220
# match:2221
# match:2222
# match:2223
# match:2224
# match:2225
# match:2226
# match:2227
# match:2228
# match:2229
# match:2230
# match:2231
# match:2232
# match:2233
# match:2234
# match:2235
# match:2236
# match:2237
# match:2238
# match:2239
# match:2240
# match:2241
# match:2242
# match:2243
# match:2244
# match:2245
# match:2246
# match:2247
# match:2248
# match:2249
# match:2250
# match:2251
# match:2252
# match:2253
# match:2254
# match:2255
# match:2256
# match:2257
# match:2258
# match:2259
# match:2260
# match:2261
# match:2262
# match:2263
# match:2264
# match:2265
# match:2266
# match:2267
# match:2268
# match:2269
# match:2270
# match:2271
# match:2272
# match:2273
# match:2274
# match:2275
# match:2276
# match:2277
# match:2278
# match:2279
# match:2280
# match:2281
# match:2282
# match:2283
# match:2284
# match:2285
# match:2286
# match:2287
# match:2288
# match:2289
# match:2290
# match:2291
# match:2292
# match:2293
# match:2294
# match:2295
# match:2296
# match:2297
# match:2298
# match:2299
# match:2300
# match:2301
# match:2302
# match:2303
# match:2304
# match:2305
# match:2306
# match:2307
# match:2308
# match:2309
# match:2310
# match:2311
# match:2312
# match:2313
# match:2314
# match:2315
# match:2316
# match:2317
# match:2318
# match:2319
# match:2320
# match:2321
# match:2322
# match:2323
# match:2324
# match:2325
# match:2326
# match:2327
# match:2328
# match:2329
# match:2330
# match:2331
# match:2332
# match:2333
# match:2334
# match:2335
# match:2336
# match:2337
# match:2338
# match:2339
# match:2340
# match:2341
# match:2342
# match:2343
# match:2344
# match:2345
# match:2346
# match:2347
# match:2348
# match:2349
# match:2350
# match:2351
# match:2352
# match:2353
# match:2354
# match:2355
# match:2356
# match:2357
# match:2358
# match:2359
# match:2360
# match:2361
# match:2362
# match:2363
# match:2364
# match:2365
# match:2366
# match:2367
# match:2368
# match:2369
# match:2370
# match:2371
# match:2372
# match:2373
# match:2374
# match:2375
# match:2376
# match:2377
# match:2378
# match:2379
# match:2380
# match:2381
# match:2382
# match:2383
# match:2384
# match:2385
# match:2386
# match:2387
# match:2388
# match:2389
# match:2390
# match:2391
# match:2392
# match:2393
# match:2394
# match:2395
# match:2396
# match:2397
# match:2398
# match:2399
# match:2400
# match:2401
# match:2402
# match:2403
# match:2404
# match:2405
# match:2406
# match:2407
# match:2408
# match:2409
# match:2410
# match:2411
# match:2412
# match:2413
# match:2414
# match:2415
# match:2416
# match:2417
# match:2418
# match:2419
# match:2420
# match:2421
# match:2422
# match:2423
# match:2424
# match:2425
# match:2426
# match:2427
# match:2428
# match:2429
# match:2430
# match:2431
# match:2432
# match:2433
# match:2434
# match:2435
# match:2436
# match:2437
# match:2438
# match:2439
# match:2440
# match:2441
# match:2442
# match:2443
# match:2444
# match:2445
# match:2446
# match:2447
# match:2448
# match:2449
# match:2450
# match:2451
# match:2452
# match:2453
# match:2454
# match:2455
# match:2456
# match:2457
# match:2458
# match:2459
# match:2460
# match:2461
# match:2462
# match:2463
# match:2464
# match:2465
# match:2466
# match:2467
# match:2468
# match:2469
# match:2470
# match:2471
# match:2472
# match:2473
# match:2474
# match:2475
# match:2476
# match:2477
#         match_id        date match_type                 event_name  innings  \
# 1085343    64814  2002-12-29        ODI  India tour of New Zealand        1
# 1085344    64814  2002-12-29        ODI  India tour of New Zealand        1
# 1085345    64814  2002-12-29        ODI  India tour of New Zealand        1
# 1085346    64814  2002-12-29        ODI  India tour of New Zealand        1
# 1085347    64814  2002-12-29        ODI  India tour of New Zealand        1
# ...          ...         ...        ...                        ...      ...
# 1315386  1442992  2024-08-07        ODI    India tour of Sri Lanka        2
# 1315387  1442992  2024-08-07        ODI    India tour of Sri Lanka        2
# 1315388  1442992  2024-08-07        ODI    India tour of Sri Lanka        2
# 1315389  1442992  2024-08-07        ODI    India tour of Sri Lanka        2
# 1315390  1442992  2024-08-07        ODI    India tour of Sri Lanka        2
#
#         match_id_inn batting_team bowling_team  over  ball  ...  match_number  \
# 1085343      64814-1  New Zealand        India     0     1  ...          1927
# 1085344      64814-1  New Zealand        India     0     2  ...          1927
# 1085345      64814-1  New Zealand        India     0     3  ...          1927
# 1085346      64814-1  New Zealand        India     0     4  ...          1927
# 1085347      64814-1  New Zealand        India     0     5  ...          1927
# ...              ...          ...          ...   ...   ...  ...           ...
# 1315386    1442992-2        India    Sri Lanka    25     3  ...          4754
# 1315387    1442992-2        India    Sri Lanka    25     4  ...          4754
# 1315388    1442992-2        India    Sri Lanka    25     5  ...          4754
# 1315389    1442992-2        India    Sri Lanka    25     6  ...          4754
# 1315390    1442992-2        India    Sri Lanka    26     1  ...          4754
#
#         team_runs  team_balls  team_wicket      new_batter batter_runs  \
# 1085343         1           1            0            None           0
# 1085344         1           2            0            None           0
# 1085345         1           3            0            None           0
# 1085346         2           4            0            None           1
# 1085347         2           5            0            None           0
# ...           ...         ...          ...             ...         ...
# 1315386       138         153            8            None          30
# 1315387       138         154            8            None          30
# 1315388       138         155            8            None          30
# 1315389       138         156            9            None          30
# 1315390       138         157           10  Mohammed Siraj           6
#
#          batter_balls  bowler_wicket                    batting_partners  \
# 1085343             1              0              (NJ Astle, SP Fleming)
# 1085344             1              0              (NJ Astle, SP Fleming)
# 1085345             2              0              (NJ Astle, SP Fleming)
# 1085346             3              0              (NJ Astle, SP Fleming)
# 1085347             2              0              (NJ Astle, SP Fleming)
# ...               ...            ...                                 ...
# 1315386            22              0  (Kuldeep Yadav, Washington Sundar)
# 1315387            23              0  (Kuldeep Yadav, Washington Sundar)
# 1315388            24              0  (Kuldeep Yadav, Washington Sundar)
# 1315389            25              1  (Kuldeep Yadav, Washington Sundar)
# 1315390            30              1     (Kuldeep Yadav, Mohammed Siraj)
#
#             next_batter
# 1085343            None
# 1085344            None
# 1085345            None
# 1085346            None
# 1085347            None
# ...                 ...
# 1315386            None
# 1315387            None
# 1315388            None
# 1315389  Mohammed Siraj
# 1315390            None
#
# [1315391 rows x 63 columns]

# %% [markdown]
# <h1>Partnership Analysis</h1>

# %%
import pandas as pd

# Group by and calculate partnership runs and balls
x = df.groupby(['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners'])[['runs_total', 'balls_faced']].sum().reset_index().rename(columns={'runs_total' :  'partnership_runs','balls_faced' :  'partnership_balls'})


y = df.groupby(['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners', 'batter'])[['runs_batter', 'balls_faced']].sum().reset_index()

# Merge the two dataframes
z = x.merge(y, on=['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batting_partners'], how='left')

# Handle the case where only one batter contributed to the partnership
one_batter_contributions = z.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batting_partners']).filter(lambda g :   len(g)   ==   1)
one_batter_contributions['missing_batter'] = one_batter_contributions.apply(lambda row :   [b for b in row['batting_partners'] if b.strip() != row['batter']][0], axis=1)

# Create missing batter rows with 0 runs and balls faced
missing_batter = one_batter_contributions.copy()
missing_batter['batter'] = missing_batter['missing_batter']
missing_batter['runs_batter'] = 0
missing_batter['balls_faced'] = 0
missing_batter = missing_batter.drop(columns=['missing_batter'])

# Combine all batter contributions
combined = pd.concat([z, missing_batter], ignore_index=True)

# Split batters into batter_1 and batter_2
combined['batter_1'], combined['batter_2'] = zip(*combined['batting_partners'])

# Assign runs and balls faced to each batter
combined['batter_1_runs'] = combined.apply(lambda row :   row['runs_batter'] if row['batter']   ==   row['batter_1'] else 0, axis=1)
combined['batter_1_balls'] = combined.apply(lambda row :   row['balls_faced'] if row['batter']   ==   row['batter_1'] else 0, axis=1)
combined['batter_2_runs'] = combined.apply(lambda row :   row['runs_batter'] if row['batter']   ==   row['batter_2'] else 0, axis=1)
combined['batter_2_balls'] = combined.apply(lambda row :   row['balls_faced'] if row['batter']   ==   row['batter_2'] else 0, axis=1)

# Aggregate the final partnership data
final = combined.groupby(['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners', 'partnership_runs', 'partnership_balls', 'batter_1', 'batter_2']).agg({
    'batter_1_runs' :  'sum', 
    'batter_1_balls' :  'sum', 
    'batter_2_runs' :  'sum', 
    'batter_2_balls' :  'sum'
}).reset_index()

# Calculate strike rates and percentage contribution
final['batter_1_SR'] = round(final['batter_1_runs'] * 100 / final['batter_1_balls'], 2)
final['batter_2_SR'] = round(final['batter_2_runs'] * 100 / final['batter_2_balls'], 2)
final['batter_1_%'] = round(final['batter_1_runs'] * 100 / final['partnership_runs'], 2)
final['batter_2_%'] = round(final['batter_2_runs'] * 100 / final['partnership_runs'], 2)

# Add partnership wickets information
partnership_wickets = df.groupby(['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners']).agg({'team_wicket' :   'min'}).reset_index().assign(team_wicket=lambda x :   x['team_wicket'] + 1)
final = final.merge(partnership_wickets, on=['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners'], how='left')
final = final.rename(columns={'team_wicket' :   'partnership_wicket'})

# Add partnership start runs and end runs
partnership_runs = df.groupby(['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners']).agg({
    'team_runs' :   ['first', 'last'],
    'team_wicket' :  ['first','last']
}).reset_index()
partnership_runs.columns = ['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batting_partners', 'partnership_start_runs', 'partnership_end_runs','partnership_start_wkts','partnership_end_wkts']
final = final.merge(partnership_runs, on=['match_id_inn', 'date','batting_team', 'bowling_team', 'batting_partners'], how='left')

# Determine if the partnership is unbeaten
final['unbeaten'] = final['partnership_start_wkts']   ==   final['partnership_end_wkts']

# Select final columns
final = final[['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batting_partners', 
               'partnership_runs', 'partnership_balls', 'partnership_wicket', 
               'batter_1', 'batter_1_runs', 'batter_1_balls', 'batter_1_SR', 'batter_1_%',
               'batter_2', 'batter_2_runs', 'batter_2_balls', 'batter_2_SR', 'batter_2_%',
               'partnership_start_runs', 'partnership_start_wkts', 'partnership_end_runs', 'partnership_end_wkts','unbeaten']]

final
# Out:
#       match_id_inn        date          batting_team          bowling_team  \
# 0        1000887-1  2017-01-13             Australia              Pakistan
# 1        1000887-1  2017-01-13             Australia              Pakistan
# 2        1000887-1  2017-01-13             Australia              Pakistan
# 3        1000887-1  2017-01-13             Australia              Pakistan
# 4        1000887-1  2017-01-13             Australia              Pakistan
# ...            ...         ...                   ...                   ...
# 38798     997995-1  2016-08-16  United Arab Emirates              Scotland
# 38799     997995-2  2016-08-16              Scotland  United Arab Emirates
# 38800     997995-2  2016-08-16              Scotland  United Arab Emirates
# 38801     997995-2  2016-08-16              Scotland  United Arab Emirates
# 38802     997995-2  2016-08-16              Scotland  United Arab Emirates
#
#                       batting_partners  partnership_runs  partnership_balls  \
# 0                (B Stanlake, MS Wade)                33                 26
# 1                   (CA Lynn, TM Head)                39                 28
# 2                 (DA Warner, TM Head)                13                 27
# 3               (GJ Maxwell, MR Marsh)                11                 20
# 4                (GJ Maxwell, MS Wade)                82                 88
# ...                                ...               ...                ...
# 38798  (Rameez Shahzad, Shaiman Anwar)                43                 25
# 38799         (CD Wallace, KJ Coetzer)                15                 13
# 38800         (CS MacLeod, KJ Coetzer)                28                 40
# 38801         (CS MacLeod, PL Mommsen)               165                214
# 38802      (PL Mommsen, RD Berrington)                21                 19
#
#        partnership_wicket        batter_1  batter_1_runs  ...       batter_2  \
# 0                      10      B Stanlake              1  ...        MS Wade
# 1                       3         CA Lynn             16  ...        TM Head
# 2                       1       DA Warner              7  ...        TM Head
# 3                       5      GJ Maxwell              9  ...       MR Marsh
# 4                       6      GJ Maxwell             51  ...        MS Wade
# ...                   ...             ...            ...  ...            ...
# 38798                   5  Rameez Shahzad             16  ...  Shaiman Anwar
# 38799                   1      CD Wallace              6  ...     KJ Coetzer
# 38800                   2      CS MacLeod             12  ...     KJ Coetzer
# 38801                   3      CS MacLeod             91  ...     PL Mommsen
# 38802                   4      PL Mommsen              6  ...  RD Berrington
#
#        batter_2_runs  batter_2_balls batter_2_SR  batter_2_%  \
# 0                 31              20      155.00       93.94
# 1                 21              16      131.25       53.85
# 2                  5               9       55.56       38.46
# 3                  2               9       22.22       18.18
# 4                 28              43       65.12       34.15
# ...              ...             ...         ...         ...
# 38798             25              12      208.33       58.14
# 38799              9               6      150.00       60.00
# 38800             16              22       72.73       57.14
# 38801             74             110       67.27       44.85
# 38802             15              13      115.38       71.43
#
#        partnership_start_runs  partnership_start_wkts  partnership_end_runs  \
# 0                         235                       9                   268
# 1                          13                       2                    52
# 2                           0                       0                    13
# 3                          68                       4                    78
# 4                          79                       5                   160
# ...                       ...                     ...                   ...
# 38798                     144                       4                   187
# 38799                       4                       0                    15
# 38800                      19                       1                    43
# 38801                      43                       2                   208
# 38802                     208                       3                   229
#
#        partnership_end_wkts  unbeaten
# 0                         9      True
# 1                         3     False
# 2                         1     False
# 3                         5     False
# 4                         6     False
# ...                     ...       ...
# 38798                     5     False
# 38799                     1     False
# 38800                     2     False
# 38801                     3     False
# 38802                     3      True
#
# [38803 rows x 23 columns]

# %%
partnerships = final.groupby(['batting_partners','batter_1','batter_2']).agg({
    'partnership_runs' :   ['sum', 'max'],
    'partnership_balls' :   'sum',
    'batter_1_runs' :   'sum',
    'batter_1_balls' :   'sum',
    'batter_2_runs' :   'sum',
    'batter_2_balls' :   'sum',
    'unbeaten' :   'sum',
    'match_id_inn' :   'nunique'
}).reset_index()

# Flattening the MultiIndex columns
partnerships.columns = ['batting_partners', 'batter_1', 'batter_2',
                        'partnership_runs', 'Highest', 'partnership_balls',
                        'batter_1_runs', 'batter_1_balls', 'batter_2_runs', 
                        'batter_2_balls', 'notouts', 'innings']

# Calculating additional columns
partnerships['batter_1_SR'] = round(partnerships['batter_1_runs'] * 100 / partnerships['batter_1_balls'], 2)
partnerships['batter_2_SR'] = round(partnerships['batter_2_runs'] * 100 / partnerships['batter_2_balls'], 2)
partnerships['batter_1_%'] = round(partnerships['batter_1_runs'] * 100 / partnerships['partnership_runs'], 2)
partnerships['batter_2_%'] = round(partnerships['batter_2_runs'] * 100 / partnerships['partnership_runs'], 2)
partnerships['sr_diff'] = abs(partnerships['batter_1_SR'] - partnerships['batter_2_SR'])

# Selecting and sorting the final columns
partnerships = partnerships[['batting_partners', 'innings', 'notouts', 'partnership_runs', 'partnership_balls', 
                             'Highest', 'batter_1', 'batter_1_runs', 'batter_1_balls', 
                             'batter_1_%', 'batter_1_SR', 'batter_2', 'batter_2_runs', 
                             'batter_2_balls', 'batter_2_%', 'batter_2_SR', 'sr_diff']]

# Filtering and sorting the results
result = partnerships[partnerships['partnership_runs'] >= 1000].sort_values(by='sr_diff', ascending=False).head(30)

result
# Out:
#                         batting_partners  innings  notouts  partnership_runs  \
# 5739                (R Dravid, V Sehwag)       39        2              2203
# 5497       (NT Paranavitana, TM Dilshan)       39        4              1509
# 2785               (G Gambhir, V Sehwag)       77        3              3814
# 1796             (CJL Rogers, DA Warner)       41        1              2053
# 2121              (DA Warner, EJM Cowan)       30        0              1291
# 1040        (Azhar Ali, Mohammad Hafeez)       36        4              1554
# 1333           (BJ Watling, LRPL Taylor)       21        4              1089
# 989         (Asad Shafiq, Sarfraz Ahmed)       28        2              1275
# 4638                 (M Vijay, S Dhawan)       41        1              1748
# 1732                 (CH Gayle, D Ganga)       25        2              1051
# 5711               (Q de Kock, T Bavuma)       28        2              1017
# 2833             (GC Smith, ND McKenzie)       27        2              1664
# 6221        (TM Dilshan, TT Samaraweera)       20        0              1190
# 1331         (BJ Watling, KS Williamson)       20        2              1068
# 1738                    9      Ahmed Raza             27  ...              20
# 25475                  10    Abdul Razzaq             32  ...               1
# 29927                   9        MS Dhoni             30  ...               1
# 3470                   10    B Muzarabani              0  ...              38
# 34955                  10     NLTC Perera             30  ...              10
# 12979                   1     LV van Beek             30  ...               0
# 29483                  10    Abdur Razzak             27  ...               1
# 9336                   10        J Little              0  ...              11
# 21738                   1    SM Warnapura              0  ...              21
# 10358                   9     Aaron Jones             27  ...               0
# 21942                   1        CH Gayle             27  ...               8
# 37436                   8      GJ Maxwell             27  ...               0
# 17889                   6     Aftab Ahmed             25  ...              17
# 2824                    9     Rashid Khan             23  ...               8
# 30516                   9       MM Sharma              0  ...              19
# 36838                   7      AD Mathews             20  ...               4
# 14967                   1      L Louwrens              0  ...              18
# 25476                   8    Abdul Razzaq             26  ...               5
# 28454                  10     LL Tsotsobe              0  ...              13
#
#        batter_2_SR  batter_2_% partnership_start_runs  partnership_start_wkts  \
# 3891        220.00       94.83                    133                       9
# 288         200.00       88.89                    226                       9
# 28947         0.00        0.00                    182                       9
# 35596         0.00        0.00                    119                       9
# 34660         0.00        0.00                    209                       9
# 8765        150.00       95.45                    167                       9
# 4318          0.00        0.00                    249                       9
# 25308       125.93       87.18                      0                       0
# 12371       145.83       94.59                    185                       9
# 13808         0.00        0.00                    133                       9
# 12439         0.00        0.00                    281                       9
# 1738          0.00        0.00                    149                       8
# 25475         0.00        0.00                    261                       9
# 29927         0.00        0.00                    267                       8
# 3470         81.58      100.00                    103                       9
# 34955         0.00        0.00                    149                       9
# 12979          NaN        0.00                      4                       0
# 29483         0.00        0.00                    230                       9
# 9336        236.36       92.86                    188                       9
# 21738       119.05       89.29                      0                       0
# 10358          NaN        0.00                    269                       8
# 21942         0.00        0.00                      2                       0
# 37436          NaN        0.00                    325                       7
# 17889         0.00        0.00                     85                       5
# 2824          0.00        0.00                    142                       8
# 30516       110.53       77.78                    190                       8
# 36838         0.00        0.00                    264                       6
# 14967       105.56       70.37                      1                       0
# 25476         0.00        0.00                    228                       7
# 28454       200.00      100.00                    182                       9
#
#        partnership_end_runs  partnership_end_wkts  unbeaten     max  min
# 3891                    189                    10     False   94.83    0
# 288                     280                    10     False   88.89    0
# 28947                   233                     9      True  100.00    0
# 35596                   165                    10     False   91.30    0
# 34660                   253                    10     False   97.73    0
# 8765                    210                    10     False   95.45    0
# 4318                    286                    10     False  100.00    0
# 25308                    39                     1     False   87.18    0
# 12371                   222                    10     False   94.59    0
# 13808                   167                    10     False  100.00    0
# 12439                   315                     9      True   97.06    0
# 1738                    182                     9     False   81.82    0
# 25475                   289                     9      True  100.00    0
# 29927                   299                     9     False   93.75    0
# 3470                    134                    10     False  100.00    0
# 34955                   180                    10     False   96.77    0
# 12979                    30                     0      True  100.00    0
# 29483                   252                     9      True   96.43    0
# 9336                    216                    10     False   92.86    0
# 21738                    28                     1     False   89.29    0
# 10358                   295                     8      True  100.00    0
# 21942                    27                     1     False  100.00    0
# 37436                   348                     8     False  100.00    0
# 17889                   112                     6     False   92.59    0
# 2824                    169                     9     False   85.19    0
# 30516                   217                     9     False   77.78    0
# 36838                   285                     7     False   74.07    0
# 14967                    27                     1     False   70.37    0
# 25476                   254                     8     False  100.00    0
# 28454                   208                    10     False  100.00    0
#
# [30 rows x 25 columns]

# %% [markdown]
# <h1>Entry Point Analysis</h1>

# %%
# Adjust team runs and balls for the striker's first appearance
striker_first = df.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter']).agg({
    'team_runs' :   'first', 
    'team_balls' :   'first',
    'team_wicket' :   'first',
    'runs_total' :   'first', 
    'valid_ball' :   'first',
    'bat_pos'  :   'first'
}).reset_index()

# Adjust team runs and balls by subtracting the batter's contributions
striker_first['adjusted_team_runs'] = striker_first['team_runs'] - striker_first['runs_total']
striker_first['adjusted_team_balls'] = striker_first['team_balls'] - striker_first['valid_ball']


# Rename columns for merging consistency
striker_first = striker_first.rename(columns={'adjusted_team_runs' :   'entry_runs', 
                                              'adjusted_team_balls' :   'entry_balls',
                                              'team_wicket' :  'entry_wickets'})

# Find the first occurrence of a batter as a non-striker without adjustments
non_striker_first = df.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'non_striker']).agg({
    'team_runs' :   'first', 
    'team_balls' :   'first',
    'runs_total' :   'first', 
    'valid_ball' :   'first',
    'team_wicket' :   'first',
    'non_striker_pos'  :   'first'
}).reset_index().rename(columns={'non_striker' :   'batter'})

non_striker_first['adjusted_team_runs'] = non_striker_first['team_runs'] - non_striker_first['runs_total']
non_striker_first['adjusted_team_balls'] = non_striker_first['team_balls'] - non_striker_first['valid_ball']

non_striker_first = non_striker_first.rename(columns={'adjusted_team_runs' :   'entry_runs', 
                                              'adjusted_team_balls' :   'entry_balls',
                                              'team_wicket' :  'entry_wickets',
                                              'non_striker_pos' :  'bat_pos'})
entry_point_first = pd.concat([striker_first, non_striker_first]).sort_values(by=['match_id_inn', 'batter', 'entry_balls']).drop_duplicates(subset=['match_id_inn', 'batter'], keep='first').reset_index(drop=True)

striker_last = df.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter']).agg({
    'team_runs' :   'last', 
    'team_balls' :   'last', 
    'team_wicket' :   'last'
}).reset_index()



# Rename columns for merging consistency
striker_last = striker_last.rename(columns={'team_runs' :   'exit_runs', 
                                            'team_balls' :   'exit_balls',
                                            'team_wicket' :   'exit_wickets'})

# Find the first occurrence of a batter as a non-striker without adjustments
non_striker_last = df.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'non_striker']).agg({
    'team_runs' :   'last', 
    'team_balls' :   'last',
    'team_wicket' :   'last'
}).reset_index().rename(columns={'non_striker' :   'batter'})


non_striker_last = non_striker_last.rename(columns={'team_runs' :   'exit_runs', 
                                              'team_balls' :   'exit_balls',
                                                   'team_wicket' :   'exit_wickets'})

entry_point_last = pd.concat([striker_last, non_striker_last]).sort_values(by=['match_id_inn', 'batter', 'exit_balls',],ascending=False).drop_duplicates(subset=['match_id_inn', 'batter'], keep='first').reset_index(drop=True)

w=entry_point_first.merge(entry_point_last,on=['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter'])
x=df.groupby(['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter'])[['runs_batter','balls_faced']].sum()
w=w.merge(x,on=['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter'])
w['fifties']=(w['runs_batter']>=50)&(w['runs_batter']<=99)
w['hundreds']=w['runs_batter']>=100
w['team_runs']=w['exit_runs']-w['entry_runs']
w['wkts']=w['exit_wickets']-w['entry_wickets']
w=w[['match_id_inn', 'date', 'batting_team', 'bowling_team', 'batter','entry_runs','entry_balls','entry_wickets','exit_runs','exit_balls','exit_wickets','team_runs','wkts','runs_batter','balls_faced','bat_pos','fifties','hundreds']]
w
# Out:
#       match_id_inn        date batting_team          bowling_team  \
# 0        1000887-1  2017-01-13    Australia              Pakistan
# 1        1000887-1  2017-01-13    Australia              Pakistan
# 2        1000887-1  2017-01-13    Australia              Pakistan
# 3        1000887-1  2017-01-13    Australia              Pakistan
# 4        1000887-1  2017-01-13    Australia              Pakistan
# ...            ...         ...          ...                   ...
# 43182     997995-2  2016-08-16     Scotland  United Arab Emirates
# 43183     997995-2  2016-08-16     Scotland  United Arab Emirates
# 43184     997995-2  2016-08-16     Scotland  United Arab Emirates
# 43185     997995-2  2016-08-16     Scotland  United Arab Emirates
# 43186     997995-2  2016-08-16     Scotland  United Arab Emirates
#
#               batter  entry_runs  entry_balls  entry_wickets  exit_runs  \
# 0         B Stanlake         235          274              9        268
# 1            CA Lynn          13           28              2         52
# 2          DA Warner           0            0              0         13
# 3         GJ Maxwell          67           78              4        160
# 4        JP Faulkner         160          186              6        170
# ...              ...         ...          ...            ...        ...
# 43182     CD Wallace           0            0              0         15
# 43183     CS MacLeod          15           13              1        208
# 43184     KJ Coetzer           0            0              0         43
# 43185     PL Mommsen          43           53              2        229
# 43186  RD Berrington         208          267              3        229
#
#        exit_balls  exit_wickets  team_runs  wkts  runs_batter  balls_faced  \
# 0             300             9         33     0            1            6
# 1              56             3         39     1           16           12
# 2              27             1         13     1            7           18
# 3             186             6         93     2           60           56
# 4             204             7         10     1            5           12
# ...           ...           ...        ...   ...          ...          ...
# 43182          13             1         15     1            6            7
# 43183         267             3        193     2          103          122
# 43184          53             2         43     2           25           28
# 43185         286             3        186     1           80          116
# 43186         286             3         21     0           15           13
#
#        bat_pos  fifties  hundreds
# 0           11    False     False
# 1            4    False     False
# 2            1    False     False
# 3            6     True     False
# 4            8    False     False
# ...        ...      ...       ...
# 43182        2    False     False
# 43183        3    False      True
# 43184        1    False     False
# 43185        4     True     False
# 43186        5    False     False
#
# [43187 rows x 18 columns]

# %%
z=w[(w['entry_balls']<90)&(w['bat_pos']>=5)].groupby('batter').agg({'match_id_inn' :  'nunique',
                                                                  'bat_pos' :  'median',
                                                                  'entry_runs' :  'mean',
                                                                  'entry_balls' :  'mean',
                                                                  'exit_runs' :  'mean',
                                                                  'exit_balls' :  'mean',
                                                                  'team_runs' :  'mean',
                                                                  'runs_batter' :  ['sum','mean'],
                                                                  'fifties' :  'sum',
                                                                  'hundreds' :  'sum'}).reset_index()
z.sort_values(by=[('match_id_inn','nunique'),('runs_batter','mean')],ascending=False).head(50)
# Out:
#                 batter match_id_inn bat_pos entry_runs entry_balls  \
#                             nunique  median       mean        mean
# 527    Shakib Al Hasan           49     5.0  35.979592   53.897959
# 15          AD Mathews           44     5.0  49.704545   62.340909
